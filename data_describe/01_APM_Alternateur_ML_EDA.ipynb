# %% [markdown]
# # APM Alternateur - Analyse Exploratoire des Données (EDA)
#
# ## Description du Dataset
# Ce notebook analyse le fichier **APM_Alternateur_ML.csv**.
#
# **Caractéristiques principales:**
# - **525,591 lignes** × **26 colonnes**
# - Données temporelles à fréquence **1 minute**
# - Variables: températures stator, puissance, tension, fréquence

# %% [markdown]
# ## 1. Import des Librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

print('Librairies importées avec succès!')
# Out:
# Librairies importées avec succès!

# %% [markdown]
# ## 2. Chargement et Aperçu des Données

# %%
df = pd.read_csv('../LAST_DATA/APM_Alternateur_ML.csv')

print('=' * 80)
print('APERÇU DES DONNÉES')
print('=' * 80)
df.head(10)
# Out:
# ================================================================================
# APERÇU DES DONNÉES
# ================================================================================
#               Datetime  MODE_TAG_1  REACTIVE_LOAD  SPEED_CTRL_pct  \
# 0  2025-02-02 23:58:00       -0.14          -0.49            0.00
# 1  2025-02-02 23:59:00       -0.14          -0.49           -0.00
# 2  2025-02-03 00:00:00       -0.14          -0.49            0.00
# 3  2025-02-03 00:01:00       -0.14          -0.49            0.00
# 4  2025-02-03 00:02:00       -0.14          -0.49           -0.00
# 5  2025-02-03 00:03:00       -0.14          -0.48            0.00
# 6  2025-02-03 00:04:00       -0.14          -0.48           -0.00
# 7  2025-02-03 00:05:00       -0.14          -0.48           -0.00
# 8  2025-02-03 00:06:00       -0.14          -0.48           -0.00
# 9  2025-02-03 00:07:00       -0.14          -0.48           -0.00
#
#    STATOR_PHASE_A_WINDING_TEMP_1_degC  STATOR_PHASE_A_WINDING_TEMP_2_degC  \
# 0                               31.01                               31.20
# 1                               31.01                               31.20
# 2                               31.01                               31.20
# 3                               31.01                               31.20
# 4                               31.01                               31.20
# 5                               31.01                               31.21
# 6                               31.01                               31.21
# 7                               31.01                               31.21
# 8                               31.01                               31.21
# 9                               31.01                               31.21
#
#    STATOR_PHASE_A_WINDING_TEMP_3_degC  STATOR_PHASE_B_WINDING_TEMP_1_degC  \
# 0                               34.98                               34.84
# 1                               34.98                               34.83
# 2                               34.98                               34.82
# 3                               34.97                               34.82
# 4                               34.97                               34.82
# 5                               34.98                               34.81
# 6                               34.97                               34.81
# 7                               34.97                               34.80
# 8                               34.97                               34.80
# 9                               34.97                               34.80
#
#    STATOR_PHASE_B_WINDING_TEMP_2_degC  STATOR_PHASE_B_WINDING_TEMP_3_degC  \
# 0                               29.51                               31.11
# 1                               29.51                               31.11
# 2                               29.51                               31.11
# 3                               29.51                               31.11
# 4                               29.50                               31.11
# 5                               29.50                               31.11
# 6                               29.50                               31.11
# 7                               29.50                               31.11
# 8                               29.50                               31.11
# 9                               29.50                               31.12
#
#    STATOR_PHASE_C_WINDING_TEMP_1_degC  STATOR_PHASE_C_WINDING_TEMP_2_degC  \
# 0                               34.93                               31.82
# 1                               34.93                               31.82
# 2                               34.93                               31.82
# 3                               34.93                               31.82
# 4                               34.93                               31.82
# 5                               34.93                               31.82
# 6                               34.93                               31.82
# 7                               34.93                               31.82
# 8                               34.94                               31.83
# 9                               34.93                               31.83
#
#    STATOR_PHASE_C_WINDING_TEMP_3_degC  TERMINAL_VOLTAGE_kV  FREQUENCY_Hz  \
# 0                               34.20                -0.00          0.00
# 1                               34.19                 0.00         -0.00
# 2                               34.19                -0.00         -0.00
# 3                               34.18                -0.00         -0.00
# 4                               34.18                 0.00          0.00
# 5                               34.17                -0.00          0.00
# 6                               34.17                 0.00          0.00
# 7                               34.17                 0.00          0.00
# 8                               34.16                 0.00         -0.00
# 9                               34.16                -0.00          0.00
#
#    ENCLOSED_HOT_AIR_TEMP_2_degC  ENCLOSED_HOT_AIR_TEMP_1_degC  \
# 0                         27.27                         27.56
# 1                         27.26                         27.55
# 2                         27.25                         27.53
# 3                         27.25                         27.52
# 4                         27.24                         27.51
# 5                         27.24                         27.49
# 6                         27.23                         27.47
# 7                         27.23                         27.46
# 8                         27.22                         27.45
# 9                         27.22                         27.43
#
#    ENCLOSED_COLD_AIR_TEMP_2_degC  ENCLOSED_COLD_AIR_TEMP_1_degC  \
# 0                          31.91                          31.91
# 1                          31.90                          31.90
# 2                          31.90                          31.90
# 3                          31.90                          31.89
# 4                          31.89                          31.89
# 5                          31.89                          31.89
# 6                          31.88                          31.88
# 7                          31.88                          31.88
# 8                          31.87                          31.87
# 9                          31.87                          31.87
#
#    AMBIENT_AIR_TEMP_C  Year  Month  Day  Hour  Minute  DayOfWeek  Quarter  \
# 0               10.97  2025      2    2    23      58          6        1
# 1               10.98  2025      2    2    23      59          6        1
# 2               10.98  2025      2    3     0       0          0        1
# 3               10.99  2025      2    3     0       1          0        1
# 4               11.00  2025      2    3     0       2          0        1
# 5               11.01  2025      2    3     0       3          0        1
# 6               11.02  2025      2    3     0       4          0        1
# 7               11.03  2025      2    3     0       5          0        1
# 8               11.04  2025      2    3     0       6          0        1
# 9               11.05  2025      2    3     0       7          0        1
#
#    SPEED_rpm  P_ACTIVE_MW  P_REACTIVE_MVAR  P_APPARENT_MVA  POWER_FACTOR  \
# 0       0.03        -0.14            -0.49            0.51         -0.28
# 1      -0.03        -0.14            -0.49            0.51         -0.27
# 2       0.03        -0.14            -0.49            0.51         -0.28
# 3       0.03        -0.14            -0.49            0.51         -0.28
# 4      -0.03        -0.14            -0.49            0.51         -0.28
# 5       0.03        -0.14            -0.48            0.50         -0.27
# 6      -0.03        -0.14            -0.48            0.50         -0.28
# 7      -0.03        -0.14            -0.48            0.50         -0.28
# 8      -0.03        -0.14            -0.48            0.50         -0.28
# 9      -0.03        -0.14            -0.48            0.50         -0.27
#
#    TEMP_PHASE_A_MEAN_degC  TEMP_PHASE_B_MEAN_degC  TEMP_PHASE_C_MEAN_degC  \
# 0                   32.40                   31.82                   33.65
# 1                   32.40                   31.82                   33.65
# 2                   32.40                   31.81                   33.65
# 3                   32.40                   31.81                   33.64
# 4                   32.39                   31.81                   33.64
# 5                   32.40                   31.81                   33.64
# 6                   32.40                   31.81                   33.64
# 7                   32.40                   31.81                   33.64
# 8                   32.40                   31.81                   33.64
# 9                   32.40                   31.81                   33.64
#
#    TEMP_STATOR_MEAN_degC  TEMP_STATOR_MAX_degC  TEMP_PHASE_IMBALANCE_degC  \
# 0                  32.62                 34.98                       1.83
# 1                  32.62                 34.98                       1.83
# 2                  32.62                 34.98                       1.83
# 3                  32.62                 34.97                       1.83
# 4                  32.62                 34.97                       1.83
# 5                  32.62                 34.98                       1.83
# 6                  32.62                 34.97                       1.83
# 7                  32.61                 34.97                       1.83
# 8                  32.61                 34.97                       1.84
# 9                  32.61                 34.97                       1.83
#
#    TEMP_HOT_AIR_MEAN_degC  TEMP_COLD_AIR_MEAN_degC  COOLING_DELTA_T_degC  \
# 0                   27.41                    31.91                 -4.49
# 1                   27.41                    31.90                 -4.50
# 2                   27.39                    31.90                 -4.51
# 3                   27.38                    31.89                 -4.51
# 4                   27.37                    31.89                 -4.52
# 5                   27.36                    31.89                 -4.52
# 6                   27.35                    31.88                 -4.53
# 7                   27.34                    31.88                 -4.53
# 8                   27.34                    31.87                 -4.54
# 9                   27.32                    31.87                 -4.54
#
#    TEMP_RISE_ABOVE_AMBIENT_degC
# 0                         21.65
# 1                         21.64
# 2                         21.63
# 3                         21.62
# 4                         21.61
# 5                         21.61
# 6                         21.60
# 7                         21.59
# 8                         21.58
# 9                         21.57

# %%
print('\nINFORMATIONS SUR LE DATASET:')
df.info()
# Out:
# INFORMATIONS SUR LE DATASET:
# <class 'pandas.DataFrame'>
# RangeIndex: 525591 entries, 0 to 525590
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Datetime                            525591 non-null  str
#  1   MODE_TAG_1                          525591 non-null  float64
#  2   REACTIVE_LOAD                       525591 non-null  float64
#  3   SPEED_CTRL_pct                      525591 non-null  float64
#  4   STATOR_PHASE_A_WINDING_TEMP_1_degC  525591 non-null  float64
#  5   STATOR_PHASE_A_WINDING_TEMP_2_degC  525591 non-null  float64
#  6   STATOR_PHASE_A_WINDING_TEMP_3_degC  525591 non-null  float64
#  7   STATOR_PHASE_B_WINDING_TEMP_1_degC  525591 non-null  float64
#  8   STATOR_PHASE_B_WINDING_TEMP_2_degC  525591 non-null  float64
#  9   STATOR_PHASE_B_WINDING_TEMP_3_degC  525591 non-null  float64
#  10  STATOR_PHASE_C_WINDING_TEMP_1_degC  525591 non-null  float64
#  11  STATOR_PHASE_C_WINDING_TEMP_2_degC  525591 non-null  float64
#  12  STATOR_PHASE_C_WINDING_TEMP_3_degC  525591 non-null  float64
#  13  TERMINAL_VOLTAGE_kV                 525591 non-null  float64
#  14  FREQUENCY_Hz                        525591 non-null  float64
#  15  ENCLOSED_HOT_AIR_TEMP_2_degC        525591 non-null  float64
#  16  ENCLOSED_HOT_AIR_TEMP_1_degC        525591 non-null  float64
#  17  ENCLOSED_COLD_AIR_TEMP_2_degC       525591 non-null  float64
#  18  ENCLOSED_COLD_AIR_TEMP_1_degC       525591 non-null  float64
#  19  AMBIENT_AIR_TEMP_C                  525591 non-null  float64
#  20  Year                                525591 non-null  int64
#  21  Month                               525591 non-null  int64
#  22  Day                                 525591 non-null  int64
#  23  Hour                                525591 non-null  int64
#  24  Minute                              525591 non-null  int64
#  25  DayOfWeek                           525591 non-null  int64
#  26  Quarter                             525591 non-null  int64
#  27  SPEED_rpm                           525591 non-null  float64
#  28  P_ACTIVE_MW                         525591 non-null  float64
#  29  P_REACTIVE_MVAR                     525591 non-null  float64
#  30  P_APPARENT_MVA                      525591 non-null  float64
#  31  POWER_FACTOR                        525591 non-null  float64
#  32  TEMP_PHASE_A_MEAN_degC              525591 non-null  float64
#  33  TEMP_PHASE_B_MEAN_degC              525591 non-null  float64
#  34  TEMP_PHASE_C_MEAN_degC              525591 non-null  float64
#  35  TEMP_STATOR_MEAN_degC               525591 non-null  float64
#  36  TEMP_STATOR_MAX_degC                525591 non-null  float64
#  37  TEMP_PHASE_IMBALANCE_degC           525591 non-null  float64
#  38  TEMP_HOT_AIR_MEAN_degC              525591 non-null  float64
#  39  TEMP_COLD_AIR_MEAN_degC             525591 non-null  float64
#  40  COOLING_DELTA_T_degC                525591 non-null  float64
#  41  TEMP_RISE_ABOVE_AMBIENT_degC        525591 non-null  float64
# dtypes: float64(34), int64(7), str(1)
# memory usage: 168.4 MB

# %% [markdown]
# ## 3. Dimensions et Types de Colonnes

# %%
print('=' * 80)
print('DIMENSIONS')
print('=' * 80)
print(f'Nombre de lignes: {df.shape[0]:,}')
print(f'Nombre de colonnes: {df.shape[1]}')
print(f'\nMémoire: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB')

print('\n' + '=' * 80)
print('COLONNES')
print('=' * 80)
for i, col in enumerate(df.columns):
    print(f'{i+1:2}. {col} ({df[col].dtype})')
# Out:
# ================================================================================
# DIMENSIONS
# ================================================================================
# Nombre de lignes: 525,591
# Nombre de colonnes: 42
#
# Mémoire: 202.50 MB
#
# ================================================================================
# COLONNES
# ================================================================================
#  1. Datetime (str)
#  2. MODE_TAG_1 (float64)
#  3. REACTIVE_LOAD (float64)
#  4. SPEED_CTRL_pct (float64)
#  5. STATOR_PHASE_A_WINDING_TEMP_1_degC (float64)
#  6. STATOR_PHASE_A_WINDING_TEMP_2_degC (float64)
#  7. STATOR_PHASE_A_WINDING_TEMP_3_degC (float64)
#  8. STATOR_PHASE_B_WINDING_TEMP_1_degC (float64)
#  9. STATOR_PHASE_B_WINDING_TEMP_2_degC (float64)
# 10. STATOR_PHASE_B_WINDING_TEMP_3_degC (float64)
# 11. STATOR_PHASE_C_WINDING_TEMP_1_degC (float64)
# 12. STATOR_PHASE_C_WINDING_TEMP_2_degC (float64)
# 13. STATOR_PHASE_C_WINDING_TEMP_3_degC (float64)
# 14. TERMINAL_VOLTAGE_kV (float64)
# 15. FREQUENCY_Hz (float64)
# 16. ENCLOSED_HOT_AIR_TEMP_2_degC (float64)
# 17. ENCLOSED_HOT_AIR_TEMP_1_degC (float64)
# 18. ENCLOSED_COLD_AIR_TEMP_2_degC (float64)
# 19. ENCLOSED_COLD_AIR_TEMP_1_degC (float64)
# 20. AMBIENT_AIR_TEMP_C (float64)
# 21. Year (int64)
# 22. Month (int64)
# 23. Day (int64)
# 24. Hour (int64)
# 25. Minute (int64)
# 26. DayOfWeek (int64)
# 27. Quarter (int64)
# 28. SPEED_rpm (float64)
# 29. P_ACTIVE_MW (float64)
# 30. P_REACTIVE_MVAR (float64)
# 31. P_APPARENT_MVA (float64)
# 32. POWER_FACTOR (float64)
# 33. TEMP_PHASE_A_MEAN_degC (float64)
# 34. TEMP_PHASE_B_MEAN_degC (float64)
# 35. TEMP_PHASE_C_MEAN_degC (float64)
# 36. TEMP_STATOR_MEAN_degC (float64)
# 37. TEMP_STATOR_MAX_degC (float64)
# 38. TEMP_PHASE_IMBALANCE_degC (float64)
# 39. TEMP_HOT_AIR_MEAN_degC (float64)
# 40. TEMP_COLD_AIR_MEAN_degC (float64)
# 41. COOLING_DELTA_T_degC (float64)
# 42. TEMP_RISE_ABOVE_AMBIENT_degC (float64)

# %% [markdown]
# ## 4. Résumé Statistique

# %%
print('STATISTIQUES DESCRIPTIVES')
df.describe().T
# Out:
# STATISTIQUES DESCRIPTIVES
#                                        count    mean     std     min     25%  \
# MODE_TAG_1                         525591.00   53.52   52.28   -0.21   -0.16
# REACTIVE_LOAD                      525591.00    3.30   16.28  -46.90   -0.47
# SPEED_CTRL_pct                     525591.00   52.19   49.23   -0.00    0.00
# STATOR_PHASE_A_WINDING_TEMP_1_degC 525591.00   60.75   24.74   -0.00   35.40
# STATOR_PHASE_A_WINDING_TEMP_2_degC 525591.00   66.25   30.02   -0.00   35.62
# STATOR_PHASE_A_WINDING_TEMP_3_degC 525591.00   57.94   19.59   -0.00   38.46
# STATOR_PHASE_B_WINDING_TEMP_1_degC 525591.00   59.88   21.87   -0.00   38.11
# STATOR_PHASE_B_WINDING_TEMP_2_degC 525591.00   65.29   30.07   -0.00   34.07
# STATOR_PHASE_B_WINDING_TEMP_3_degC 525591.00   59.00   22.95   -0.00   35.56
# STATOR_PHASE_C_WINDING_TEMP_1_degC 525591.00   57.74   19.52   -0.00   38.46
# STATOR_PHASE_C_WINDING_TEMP_2_degC 525591.00   68.17   31.16   -0.00   36.30
# STATOR_PHASE_C_WINDING_TEMP_3_degC 525591.00   57.45   19.68   -0.00   37.91
# TERMINAL_VOLTAGE_kV                525591.00    8.21    7.92   -0.00    0.00
# FREQUENCY_Hz                       525591.00   26.30   24.60   -0.00    0.00
# ENCLOSED_HOT_AIR_TEMP_2_degC       525591.00   56.63   22.76   -0.00   33.94
# ENCLOSED_HOT_AIR_TEMP_1_degC       525591.00   55.95   22.24   -0.00   33.82
# ENCLOSED_COLD_AIR_TEMP_2_degC      525591.00   44.82   10.31   -0.00   35.58
# ENCLOSED_COLD_AIR_TEMP_1_degC      525591.00   44.82   10.31   -0.00   35.58
# AMBIENT_AIR_TEMP_C                 525591.00   22.40    7.17  -17.78   17.28
# Year                               525591.00 2025.09    0.29 2025.00 2025.00
# Month                              525591.00    6.53    3.45    1.00    4.00
# Day                                525591.00   15.72    8.80    1.00    8.00
# Hour                               525591.00   11.50    6.92    0.00    5.00
# Minute                             525591.00   29.50   17.32    0.00   14.00
# DayOfWeek                          525591.00    2.99    2.00    0.00    1.00
# Quarter                            525591.00    2.51    1.12    1.00    2.00
# SPEED_rpm                          525591.00 1565.68 1476.92   -0.03    0.03
# P_ACTIVE_MW                        525591.00   53.52   52.28   -0.21   -0.16
# P_REACTIVE_MVAR                    525591.00    3.30   16.28  -46.90   -0.47
# P_APPARENT_MVA                     525591.00   55.13   53.24    0.00    0.47
# POWER_FACTOR                       525591.00    0.35    0.65   -0.50   -0.33
# TEMP_PHASE_A_MEAN_degC             525591.00   61.65   24.77   -0.00   36.58
# TEMP_PHASE_B_MEAN_degC             525591.00   61.39   24.95   -0.00   36.02
# TEMP_PHASE_C_MEAN_degC             525591.00   61.12   23.43   -0.00   37.60
# TEMP_STATOR_MEAN_degC              525591.00   61.39   24.38   -0.00   36.76
# TEMP_STATOR_MAX_degC               525591.00   69.16   30.14   -0.00   38.53
# TEMP_PHASE_IMBALANCE_degC          525591.00    1.65    0.58    0.00    1.64
# TEMP_HOT_AIR_MEAN_degC             525591.00   56.29   22.50   -0.00   33.87
# TEMP_COLD_AIR_MEAN_degC            525591.00   44.82   10.31   -0.00   35.58
# COOLING_DELTA_T_degC               525591.00   11.47   12.87   -5.82   -3.12
# TEMP_RISE_ABOVE_AMBIENT_degC       525591.00   38.99   20.81   -4.12   18.17
#
#                                        50%     75%     max
# MODE_TAG_1                           86.81  106.88  123.65
# REACTIVE_LOAD                        -0.44   10.85   57.97
# SPEED_CTRL_pct                       99.90  100.01  100.51
# STATOR_PHASE_A_WINDING_TEMP_1_degC   71.27   85.64   96.07
# STATOR_PHASE_A_WINDING_TEMP_2_degC   77.43   96.84  112.75
# STATOR_PHASE_A_WINDING_TEMP_3_degC   64.84   77.71   87.18
# STATOR_PHASE_B_WINDING_TEMP_1_degC   67.41   82.03   92.59
# STATOR_PHASE_B_WINDING_TEMP_2_degC   76.85   95.73  111.19
# STATOR_PHASE_B_WINDING_TEMP_3_degC   67.80   82.19   91.71
# STATOR_PHASE_C_WINDING_TEMP_1_degC   63.73   77.50   87.24
# STATOR_PHASE_C_WINDING_TEMP_2_degC   80.52   99.83  116.00
# STATOR_PHASE_C_WINDING_TEMP_3_degC   63.90   77.29   87.15
# TERMINAL_VOLTAGE_kV                  15.00   15.99   17.02
# FREQUENCY_Hz                         49.95   50.00   50.23
# ENCLOSED_HOT_AIR_TEMP_2_degC         66.56   79.55   88.97
# ENCLOSED_HOT_AIR_TEMP_1_degC         65.24   78.37   87.85
# ENCLOSED_COLD_AIR_TEMP_2_degC        44.35   55.33   63.47
# ENCLOSED_COLD_AIR_TEMP_1_degC        44.35   55.33   63.48
# AMBIENT_AIR_TEMP_C                   22.05   27.93   53.89
# Year                               2025.00 2025.00 2026.00
# Month                                 7.00   10.00   12.00
# Day                                  16.00   23.00   31.00
# Hour                                 11.00   17.00   23.00
# Minute                               29.00   44.00   59.00
# DayOfWeek                             3.00    5.00    6.00
# Quarter                               3.00    4.00    4.00
# SPEED_rpm                          2996.93 3000.31 3015.21
# P_ACTIVE_MW                          86.81  106.88  123.65
# P_REACTIVE_MVAR                      -0.44   10.85   57.97
# P_APPARENT_MVA                       88.64  109.77  129.76
# POWER_FACTOR                          0.93    0.98    1.00
# TEMP_PHASE_A_MEAN_degC               71.20   86.75   98.29
# TEMP_PHASE_B_MEAN_degC               70.74   86.65   98.50
# TEMP_PHASE_C_MEAN_degC               69.42   84.88   96.75
# TEMP_STATOR_MEAN_degC                70.46   86.10   97.85
# TEMP_STATOR_MAX_degC                 80.52   99.83  116.00
# TEMP_PHASE_IMBALANCE_degC             1.87    2.00    2.86
# TEMP_HOT_AIR_MEAN_degC               65.91   78.96   88.41
# TEMP_COLD_AIR_MEAN_degC              44.35   55.33   63.48
# COOLING_DELTA_T_degC                 20.87   24.02   29.08
# TEMP_RISE_ABOVE_AMBIENT_degC         47.25   58.98   80.03

# %% [markdown]
# ## 5. Analyse des Valeurs Manquantes

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)

print('VALEURS MANQUANTES:')
missing_df = pd.DataFrame({'Manquantes': missing, '%': missing_pct})
print(missing_df)
print(f'\nTotal: {missing.sum()} valeurs manquantes')
# Out:
# VALEURS MANQUANTES:
#                                     Manquantes    %
# Datetime                                     0 0.00
# MODE_TAG_1                                   0 0.00
# REACTIVE_LOAD                                0 0.00
# SPEED_CTRL_pct                               0 0.00
# STATOR_PHASE_A_WINDING_TEMP_1_degC           0 0.00
# STATOR_PHASE_A_WINDING_TEMP_2_degC           0 0.00
# STATOR_PHASE_A_WINDING_TEMP_3_degC           0 0.00
# STATOR_PHASE_B_WINDING_TEMP_1_degC           0 0.00
# STATOR_PHASE_B_WINDING_TEMP_2_degC           0 0.00
# STATOR_PHASE_B_WINDING_TEMP_3_degC           0 0.00
# STATOR_PHASE_C_WINDING_TEMP_1_degC           0 0.00
# STATOR_PHASE_C_WINDING_TEMP_2_degC           0 0.00
# STATOR_PHASE_C_WINDING_TEMP_3_degC           0 0.00
# TERMINAL_VOLTAGE_kV                          0 0.00
# FREQUENCY_Hz                                 0 0.00
# ENCLOSED_HOT_AIR_TEMP_2_degC                 0 0.00
# ENCLOSED_HOT_AIR_TEMP_1_degC                 0 0.00
# ENCLOSED_COLD_AIR_TEMP_2_degC                0 0.00
# ENCLOSED_COLD_AIR_TEMP_1_degC                0 0.00
# AMBIENT_AIR_TEMP_C                           0 0.00
# Year                                         0 0.00
# Month                                        0 0.00
# Day                                          0 0.00
# Hour                                         0 0.00
# Minute                                       0 0.00
# DayOfWeek                                    0 0.00
# Quarter                                      0 0.00
# SPEED_rpm                                    0 0.00
# P_ACTIVE_MW                                  0 0.00
# P_REACTIVE_MVAR                              0 0.00
# P_APPARENT_MVA                               0 0.00
# POWER_FACTOR                                 0 0.00
# TEMP_PHASE_A_MEAN_degC                       0 0.00
# TEMP_PHASE_B_MEAN_degC                       0 0.00
# TEMP_PHASE_C_MEAN_degC                       0 0.00
# TEMP_STATOR_MEAN_degC                        0 0.00
# TEMP_STATOR_MAX_degC                         0 0.00
# TEMP_PHASE_IMBALANCE_degC                    0 0.00
# TEMP_HOT_AIR_MEAN_degC                       0 0.00
# TEMP_COLD_AIR_MEAN_degC                      0 0.00
# COOLING_DELTA_T_degC                         0 0.00
# TEMP_RISE_ABOVE_AMBIENT_degC                 0 0.00
#
# Total: 0 valeurs manquantes

# %% [markdown]
# ## 6. Distribution des Variables Principales

# %%
# Variables principales à analyser
main_vars = ['MODE_TAG_1', 'REACTIVE_LOAD', 'SPEED_CTRL_pct', 'TERMINAL_VOLTAGE_kV', 'FREQUENCY_Hz']

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, var in enumerate(main_vars):
    ax = axes[i]
    sns.histplot(df[var], kde=True, ax=ax, color='steelblue', alpha=0.7)
    ax.set_title(f'Distribution: {var}', fontsize=11, fontweight='bold')
    ax.axvline(df[var].mean(), color='red', linestyle='--', label=f'Moy: {df[var].mean():.2f}')
    ax.legend(fontsize=8)

axes[-1].set_visible(False)
plt.suptitle('Distribution des Variables Principales', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Températures du stator
temp_cols = [col for col in df.columns if 'STATOR' in col and 'TEMP' in col]

n_cols = len(temp_cols)
n_rows = (n_cols + 2) // 3
fig, axes = plt.subplots(n_rows, 3, figsize=(15, 4 * n_rows))
axes = axes.flatten()

for i, col in enumerate(temp_cols):
    ax = axes[i]
    sns.histplot(df[col], kde=True, ax=ax, color='coral', alpha=0.7)
    ax.set_title(col.replace('STATOR_', '').replace('_degC', ''), fontsize=9)

# Hide empty axes
for j in range(n_cols, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Températures du Stator', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Matrice de Corrélation

# %%
numeric_cols = [col for col in df.select_dtypes(include=[np.number]).columns 
                if col not in ['Year', 'Month', 'Day', 'Hour', 'Minute', 'DayOfWeek', 'Quarter']]

corr = df[numeric_cols].corr()

plt.figure(figsize=(16, 14))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, fmt='.2f', cmap='RdBu_r', center=0,
            square=True, linewidths=0.5, annot_kws={'size': 8})
plt.title('Matrice de Corrélation', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Visualisation Temporelle

# %%
if all(col in df.columns for col in ['Year', 'Month', 'Day', 'Hour', 'Minute']):
    df['DateTime'] = pd.to_datetime(df[['Year', 'Month', 'Day', 'Hour', 'Minute']])
    
    # Sous-échantillonner pour visualisation
    step = max(1, len(df) // 5000)
    sample = df.iloc[::step].copy()
    
    fig, axes = plt.subplots(3, 1, figsize=(16, 12), sharex=True)
    
    axes[0].plot(sample['DateTime'], sample['MODE_TAG_1'], color='blue', linewidth=0.5)
    axes[0].set_ylabel('Puissance (MW)')
    axes[0].set_title('Puissance Active')
    axes[0].fill_between(sample['DateTime'], sample['MODE_TAG_1'], alpha=0.3)
    
    temp_mean = sample[temp_cols].mean(axis=1)
    axes[1].plot(sample['DateTime'], temp_mean, color='red', linewidth=0.5)
    axes[1].set_ylabel('Temp (°C)')
    axes[1].set_title('Température Moyenne Stator')
    
    axes[2].plot(sample['DateTime'], sample['FREQUENCY_Hz'], color='green', linewidth=0.5)
    axes[2].axhline(50, color='red', linestyle='--', label='50 Hz')
    axes[2].set_ylabel('Fréquence (Hz)')
    axes[2].set_xlabel('Date')
    axes[2].legend()
    
    plt.suptitle('Évolution Temporelle', fontsize=14, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.show()

# %%
# Analyse par heure
if 'Hour' in df.columns:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    hourly_power = df.groupby('Hour')['MODE_TAG_1'].mean()
    axes[0].bar(hourly_power.index, hourly_power.values, color='steelblue', edgecolor='black')
    axes[0].set_xlabel('Heure')
    axes[0].set_ylabel('Puissance Moyenne (MW)')
    axes[0].set_title('Puissance par Heure')
    
    hourly_temp = df.groupby('Hour')[temp_cols].mean().mean(axis=1)
    axes[1].bar(hourly_temp.index, hourly_temp.values, color='coral', edgecolor='black')
    axes[1].set_xlabel('Heure')
    axes[1].set_ylabel('Température Moyenne (°C)')
    axes[1].set_title('Température par Heure')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 9. Détection des Outliers (Box Plots)

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

boxplot_vars = ['MODE_TAG_1', 'REACTIVE_LOAD', 'TERMINAL_VOLTAGE_kV', 
                'FREQUENCY_Hz', 'AMBIENT_AIR_TEMP_C', 'SPEED_CTRL_pct']

for i, var in enumerate(boxplot_vars):
    sns.boxplot(y=df[var], ax=axes[i], color='lightblue')
    axes[i].set_title(var, fontsize=11, fontweight='bold')

plt.suptitle('Box Plots - Détection des Outliers', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Box plots des températures
temp_data = df[temp_cols].melt(var_name='Capteur', value_name='Température')

plt.figure(figsize=(16, 6))
sns.boxplot(data=temp_data, x='Capteur', y='Température', palette='Reds')
plt.xticks(rotation=45, ha='right')
plt.title('Températures par Capteur', fontsize=14, fontweight='bold')
plt.ylabel('Température (°C)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Relations entre Variables

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sample = df.sample(n=min(5000, len(df)), random_state=42)

# Puissance vs Température
axes[0].scatter(sample['MODE_TAG_1'], sample['STATOR_PHASE_A_WINDING_TEMP_1_degC'], 
                alpha=0.3, s=5, c='blue')
axes[0].set_xlabel('Puissance (MW)')
axes[0].set_ylabel('Température Phase A (°C)')
axes[0].set_title('Puissance vs Température')

# Tension vs Fréquence
axes[1].scatter(sample['TERMINAL_VOLTAGE_kV'], sample['FREQUENCY_Hz'], 
                alpha=0.3, s=5, c='green')
axes[1].set_xlabel('Tension (kV)')
axes[1].set_ylabel('Fréquence (Hz)')
axes[1].set_title('Tension vs Fréquence')

# Température ambiante vs Stator
axes[2].scatter(sample['AMBIENT_AIR_TEMP_C'], sample['STATOR_PHASE_A_WINDING_TEMP_1_degC'], 
                alpha=0.3, s=5, c='red')
axes[2].set_xlabel('Température Ambiante (°C)')
axes[2].set_ylabel('Température Stator (°C)')
axes[2].set_title('Ambiante vs Stator')

plt.suptitle('Relations entre Variables', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Pair plot
key_vars = ['MODE_TAG_1', 'STATOR_PHASE_A_WINDING_TEMP_1_degC', 'TERMINAL_VOLTAGE_kV', 'FREQUENCY_Hz']
sample_small = df[key_vars].sample(n=min(1000, len(df)), random_state=42)

g = sns.pairplot(sample_small, diag_kind='kde', plot_kws={'alpha': 0.5, 's': 15})
g.figure.suptitle('Pair Plot - Variables Principales', y=1.02, fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ## 11. Conclusions
#
# ### Résumé:
# - **Qualité des données**: Pas de valeurs manquantes
# - **Puissance active**: 0-124 MW
# - **Températures stator**: ~60-115°C
# - **Fréquence**: ~50 Hz (nominal)
# - **Corrélations fortes** entre températures des phases et avec la puissance
